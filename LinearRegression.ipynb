# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline
import numpy as np
from pylab import *
import matplotlib.pyplot as plt
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds+np.random.normal(0,0.1,1000))*3

print(pageSpeeds[0],purchaseAmount[0])
# Out:
# 2.9531753107678655 91.28145119421522

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
r_value ** 2
# Out:
# 0.9907804587690999

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import *
import numpy as np
pageSpeeds=np.random.normal(3.0,1.0,1000)
purchaseAmounts=100-(pageSpeeds+np.random.normal(0,0.5,1000))*3
scatter(pageSpeeds,purchaseAmounts)

# %%
from scipy import stats
slope,intercept,r_value,p_value,std_err=stats.linregress(pageSpeeds,purchaseAmounts)
slope
# Out:
# -2.960765753451352

# %%
intercept
# Out:
# 99.94728615821748

# %%
r_value
# Out:
# -0.906298927847008

# %%
r_value**2
# Out:
# 0.8213777466166363

# %%
std_err
# Out:
# 0.04370539944104909

# %%
def predict(x):
    return x*slope+intercept
fitline=predict(pageSpeeds)
plt.scatter(pageSpeeds,purchaseAmounts)
plt.plot(pageSpeeds,fitline,'r-')
plt.show()
